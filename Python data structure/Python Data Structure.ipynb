# %% [markdown]
# ## Why python Built-In data structures?
# - To collect multiple data in a structure .
# - To collect
#
#
# #### Data structure in python
# 1. List
# 2. sets
# 3. Tuples
# 4. Dictinoary - key & value

# %% [markdown]
# ## 1. List
# - 1D
# - Hetrogenous
# - Duplicate
# - indexing and slicling is possible
# - mutable

# %%
empty_cart = []
empty_cart
# Out:
# []

# %%
type(empty_cart)
# Out:
# list

# %%
item_to_buy=["Apple","orange","Grapes","Green apple"]
item_to_buy
# Out:
# ['Apple', 'orange', 'Grapes', 'Green apple']

# %%
type(item_to_buy)
# Out:
# list

# %%
len(item_to_buy)
# Out:
# 4

# %%
item_to_buy[0]           # indexing
# Out:
# 'Apple'

# %%
item_to_buy[-3]
# Out:
# 'orange'

# %%
item_to_buy[0:3]
# Out:
# ['Apple', 'orange', 'Grapes']

# %%
item_to_buy[-1::-4]
# Out:
# ['Green apple']

# %%
item_to_buy
# Out:
# ['Apple', 'orange', 'Grapes', 'Green apple']

# %%
item_to_buy[1]="kiwi"

# %%
item_to_buy
# Out:
# ['Apple', 'kiwi', 'Grapes', 'Green apple']

# %%
item_to_buy[::-1]
# Out:
# ['Green apple', 'Grapes', 'kiwi', 'Apple']

# %%
item_to_buy[-3::-1]
# Out:
# ['kiwi', 'Apple']

# %% [markdown]
# ## 2.Sets
# - 1d
# - hetrogenous
# - it won't allow duplicate value
# - indexing and slicing is not possile
# - mutable

# %%
empty_cart_2 = set()
empty_cart_2
# Out:
# set()

# %%
type(empty_cart_2)
# Out:
# set

# %%
item_to_buy_2={"Apple","orange","Grapes","Green apple"}
item_to_buy_2
# Out:
# {'Apple', 'Grapes', 'Green apple', 'orange'}

# %%
item_to_buy_2.add('watermelon')

# %%
item_to_buy_2
# Out:
# {'Apple', 'Grapes', 'Green apple', 'orange', 'watermelon'}

# %%
item_to_buy_2.discard('watermelon')

# %%
item_to_buy_2
# Out:
# {'Apple', 'Grapes', 'Green apple', 'orange'}

# %% [markdown]
# ## 3.Tuple
# - 1D
# - hetrogenous
# - Duplicate is allowed
# - index and slicing is possible
# - immutabble

# %%
empty_cart_3 = ()
empty_cart_3
# Out:
# ()

# %%
type(empty_cart_3)
# Out:
# tuple

# %%
item_to_buy_3=("Apple","orange","Grapes","Green apple")
item_to_buy_3
# Out:
# ('Apple', 'orange', 'Grapes', 'Green apple')

# %%
item_to_buy_3[0:3]
# Out:
# ('Apple', 'orange', 'Grapes')

# %% [markdown]
# ## 4.Dictionary
# - It is a Key:value pair
#
# - 2D
# - hetrogenous
# - mutable
# - indexing and slicing is not possile
# - Don't create duplicate key, but you can create duplicate values

# %%
empty_cart_4={}
empty_cart_4
# Out:
# {}

# %%
type(empty_cart_4)
# Out:
# dict

# %%
student_mark ={"maths":90,
              "Englis":95,
              "Social":97}
student_mark
# Out:
# {'maths': 90, 'Englis': 95, 'Social': 97}

# %%
type(student_mark)
# Out:
# dict

# %%
import pandas as pd

# %%
avg_student_mark={"names":["Allan","Bala","Cherish","David"],'class 1' :[50,60,70,90],"name":["Eatting","Frank","Godson","Hen"], 'class 2' :[60,90,80,45]}
avg_student_mark
# Out:
# {'names': ['Allan', 'Bala', 'Cherish', 'David'],
#  'class 1': [50, 60, 70, 90],
#  'name': ['Eatting', 'Frank', 'Godson', 'Hen'],
#  'class 2': [60, 90, 80, 45]}

# %%
pd.DataFrame(data=avg_student_mark)
# Out:
#      names  class 1     name  class 2
# 0    Allan       50  Eatting       60
# 1     Bala       60    Frank       90
# 2  Cherish       70   Godson       80
# 3    David       90      Hen       45
